# %%
import pandas as pd
import os 
import warnings
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
warnings.filterwarnings("ignore")
crashes_df = pd.read_csv('Output/Crashes.csv')
crashes_df
# Out:
#         Unnamed: 0     RD_NO CRASH_DATE_EST_I              CRASH_DATE  \
# 0                0  JB463135              NaN  10/05/2018 02:20:00 AM
# 1                1  JB463111              NaN  10/05/2018 01:35:00 AM
# 2                2  JB463117              NaN  10/05/2018 01:03:00 AM
# 3                4  JB463078              NaN  10/05/2018 12:30:00 AM
# 4                5  JB463073              NaN  10/05/2018 12:10:00 AM
# 5                7  JB463058              NaN  10/04/2018 11:40:00 PM
# 6               10  JB463033              NaN  10/04/2018 11:04:00 PM
# 7               11  JB463070              NaN  10/04/2018 11:00:00 PM
# 8               12  JB463050              NaN  10/04/2018 10:30:00 PM
# 9               14  JB463018              NaN  10/04/2018 09:45:00 PM
# 10              16  JB463007              NaN  10/04/2018 08:59:00 PM
# 11              17  JB462946              NaN  10/04/2018 08:59:00 PM
# ...

# %%
crashes_num = len(crashes_df["RD_NO"].value_counts())
crashes_num
# Out:
# 162055

# %%
day = crashes_df['CRASH_DAY_OF_WEEK'].value_counts()
day = pd.DataFrame(day)

# %%
weather = crashes_df.groupby(['WEATHER_CONDITION']).count()["RD_NO"]
weather
# Out:
# WEATHER_CONDITION
# CLEAR                     130348
# CLOUDY/OVERCAST             4764
# FOG/SMOKE/HAZE               293
# OTHER                        440
# RAIN                       14660
# SEVERE CROSS WIND GATE        35
# SLEET/HAIL                   208
# SNOW                        4870
# UNKNOWN                     6437
# Name: RD_NO, dtype: int64

# %%
crash_type = crashes_df.groupby(['FIRST_CRASH_TYPE']).count()["RD_NO"]
crash_type = pd.DataFrame(crash_type)
crash_type.plot.barh()
plt.ylabel("Number Of Crashes") 
plt.savefig("crash_type.png")

# %%
speed_limit = crashes_df.groupby(['POSTED_SPEED_LIMIT']).count()["RD_NO"]
speed_limit = pd.DataFrame(speed_limit)
speed_limit.plot.area()
plt.ylabel("Number Of Crashes") 
plt.savefig("speed_limit.png")

# %%
control_device= crashes_df.groupby(['TRAFFIC_CONTROL_DEVICE']).count()["RD_NO"]
control_device = pd.DataFrame(crash_street)
control_device.plot.barh()
plt.ylabel("Number Of Crashes") 
plt.savefig("control_device.png")

# %%
cor = crashes_df

# %%
cor.drop("RD_NO",axis=1,inplace=True)

# %%
cor
# Out:
#         Unnamed: 0 CRASH_DATE_EST_I              CRASH_DATE  \
# 0                0              NaN  10/05/2018 02:20:00 AM
# 1                1              NaN  10/05/2018 01:35:00 AM
# 2                2              NaN  10/05/2018 01:03:00 AM
# 3                4              NaN  10/05/2018 12:30:00 AM
# 4                5              NaN  10/05/2018 12:10:00 AM
# 5                7              NaN  10/04/2018 11:40:00 PM
# 6               10              NaN  10/04/2018 11:04:00 PM
# 7               11              NaN  10/04/2018 11:00:00 PM
# 8               12              NaN  10/04/2018 10:30:00 PM
# 9               14              NaN  10/04/2018 09:45:00 PM
# 10              16              NaN  10/04/2018 08:59:00 PM
# 11              17              NaN  10/04/2018 08:59:00 PM
# 12              19              NaN  10/04/2018 08:45:00 PM
# 13              20              NaN  10/04/2018 08:30:00 PM
# 14              21              NaN  10/04/2018 08:23:00 PM
# ...

# %%
damage = cor['DAMAGE'].tolist()
speed_limit = cor['POSTED_SPEED_LIMIT'].tolist()
crash_type = cor['FIRST_CRASH_TYPE'].tolist()
traffic = cor['TRAFFIC_CONTROL_DEVICE'].tolist()
device = cor['DEVICE_CONDITION'].tolist()

# %%
plt.scatter(speed_limit,damage)
plt.xlabel("Speed Limit")
plt.ylabel("Damages")
# Out:
# Text(0,0.5,'Damages')

# %%
plt.bar(speed_limit,traffic)
plt.bar(speed_limit,device)
